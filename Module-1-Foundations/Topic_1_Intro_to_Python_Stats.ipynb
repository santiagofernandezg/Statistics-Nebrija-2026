# %% [markdown]
# # Topic 1: Introduction to Statistics with Python
# ## Applied Statistics - Spring 2026
#
# In this session, we will explore:
# 1. Basic data structures in Python.
# 2. How to calculate central tendency measures (Mean, Median).
# 3. Visualizing our first distribution.
#
# **Textbook Reference:** Python Data Science Handbook (VanderPlas) - Chapter 2 & 4.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load a classic dataset (Iris flowers)
data = sns.load_dataset('iris')

# Calculate basic stats
print("Mean Sepal Length:", data['sepal_length'].mean())
print("Standard Deviation:", data['sepal_length'].std())

# Visualizing the distribution
sns.histplot(data['sepal_length'], kde=True, color='skyblue')
plt.title('Distribution of Sepal Length')
plt.show()
# Out:
# Mean Sepal Length: 5.843333333333334
# Standard Deviation: 0.828066127977863
